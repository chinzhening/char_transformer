# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/char_transformer
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/char_transformer'
# /content/drive/.shortcut-targets-by-id/1ZdikWibndOy-EAHWOwKrJSalwWRmsckp/char_transformer

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
import optax
import pandas as pd
import time

# local imports
import models.swiglu as swiglu
import util.generation as generation

# %%
key = jax.random.key(0)

# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./data/text8_train.txt", "r") as f:
    train_text = f.read()
with open("./data/text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
def create_train_state(
    model,
    rng=jax.random.key(0),
    vocab_size=27,
    d_model=64,
    n_layers=6,
    n_heads=8,
    max_len=128,
    dropout_rate=0.1,
):
    # instantiate model
    new_model = model(
        vocab_size=vocab_size,
        d_model=d_model,
        n_layers=n_layers,
        n_heads=n_heads,
        max_len=max_len,
        mlp_ratio = 8/3,
        tie_weights=False,
        dropout_rate=0.0,
    )

    # Dummy input for shape inference
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)

    # Split RNGs: one for params, one for dropout (required even if deterministic=True)
    rng_params, rng_dropout = jax.random.split(rng)

    # Initialize parameters
    params = new_model.init(
        {"params": rng_params, "dropout": rng_dropout},
        dummy,
        deterministic=True  # no dropout during initialization
    )["params"]

    return new_model, params

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))

# %%
@jax.jit
def loss_and_metrics(logits, targets):
    """Compute cross-entropy loss and accuracy.

    Assumes `targets` contains only valid integer class ids in [0, V-1] (no -1 ignore tokens).

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) integer array with ground-truth class ids.

    Returns:
      loss: scalar average cross-entropy over all positions.
      metrics: dict with keys "loss" and "acc" (both scalars).
    """
    # Flatten batch/time dims so optax works on shape (N, V) and (N,)
    # flat_logits = logits[:,-1, :]
    # flat_targets = targets[:,-1]
    # else:
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Per-position cross-entropy, then mean over all positions
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    loss = per_pos.mean()

    # prediction over all positions
    preds = jnp.argmax(logits, axis=-1)  # (B, T)

    # compute accuracy over only the last position
    is_match = preds == targets

    # Accuracy over all positions
    acc_all = jnp.mean(is_match.astype(jnp.float32))

    # Accuracy over only last position
    acc_last = jnp.mean(is_match.astype(jnp.float32)[:,-1])

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %%
# create an update function
def train_step(params, opt_state, x, y, rng, tx, model):
    rng, swiglu_rng = jax.random.split(rng)
    def loss_fn(params):
        logits = model.apply({"params": params}, x, deterministic=True)
        loss, metrics = loss_and_metrics(logits, y)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# jit: last argument should be static because it is an object
train_step = jax.jit(train_step, static_argnames=("tx", "model"))

# %%
# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# %%
# Create the optimizer
def create_optimizer(lr, params):
    tx = optax.adam(learning_rate=lr)
    opt_state = tx.init(params)
    return tx, opt_state

# %%
def train(model, params, rng=jax.random.key(0), lr=0.001, B=128, T=32, niter=10_000):
    tx, opt_state = create_optimizer(lr, params)
    loss_history = []
    time_history = []
    time_test_history = []
    loss_test_history = []
    acc_last_test_history = []
    time_start = time.time()
    for it in range(niter):
        batch = get_batch(train_text_int, B, T)
        input, target = batch[0], batch[1]
        params_new, opt_state_new, metrics = train_step(params, opt_state, input, target, rng, tx, model)

        # update params and opt_state
        params = params_new
        opt_state = opt_state_new
        acc = metrics['acc']
        acc_last = metrics['acc_last']
        loss = metrics['loss']

        loss_history.append(loss)
        time_history.append(time.time() - time_start)

        if it % (niter // 50) == 0 or it == niter - 1:
            time_since_start = time.time() - time_start
            # compute loss on test set
            B_test, T_test = 1024, 32
            test_batch = get_batch(test_text_int, B_test, T_test)
            test_input, test_target = test_batch[0], test_batch[1]
            test_logits = None
            test_logits = model.apply({"params": params}, test_input, deterministic=True)
            test_loss, test_metrics = loss_and_metrics(test_logits, test_target)
            test_acc = test_metrics['acc']
            test_acc_last = test_metrics['acc_last']

            loss_test_history.append(test_loss)
            time_test_history.append(time_since_start)
            acc_last_test_history.append(test_acc_last)

            if it % (niter // 50) == 0 or it == niter - 1:
                print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
                print(f"\t \t loss(train :: test): {loss:.4f} :: {test_loss:.4f}")
                print(f"\t \t accuracy (train :: test): {100*acc:.1f}% :: {100*test_acc:.1f}%")
                print(f"\t \t accuracy (last character) (train :: test): {100*acc_last:.1f}% :: {100*test_acc_last:.1f}%")
                print()
    return loss_history, time_history, loss_test_history, time_test_history, acc_last_test_history, params

# %%
# Model Parameters
vocab_size= len(char_set)
d_model=256
n_heads=8
n_layers=3
max_len=128

swiglu_model, swiglu_model_params = create_train_state(
    swiglu.DecoderOnlyTransformer,
    key,
    vocab_size,
    d_model,
    n_layers,
    n_heads,
    max_len)

print(f"swiglu_wt_model_param_count: {count_params(swiglu_model_params):_}")
# Out:
# swiglu_wt_model_param_count: 2_412_796

# %%
swiglu_lr=0.00025
swiglu_B=256
swiglu_T=32
swiglu_niter=100_000

swiglu_loss_hist, swiglu_time_hist, swiglu_loss_test_hist, swiglu_time_test_hist, swiglu_acc_last_test_hist, swiglu_model_params = train(
    swiglu_model,
    swiglu_model_params,
    key,
    swiglu_lr,
    swiglu_B,
    swiglu_T,
    swiglu_niter
)
# Out:
# iteration 0  time: 9.5 seconds
# 	 	 loss(train :: test): 3.6893 :: 3.1829
# 	 	 accuracy (train :: test): 3.1% :: 12.3%
# 	 	 accuracy (last character) (train :: test): 2.0% :: 14.6%
#
# iteration 2_000  time: 19.0 seconds
# 	 	 loss(train :: test): 1.3929 :: 1.4360
# 	 	 accuracy (train :: test): 56.6% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.1%
#
# iteration 4_000  time: 26.5 seconds
# 	 	 loss(train :: test): 1.3803 :: 1.3897
# 	 	 accuracy (train :: test): 57.5% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 59.0%
#
# iteration 6_000  time: 34.0 seconds
# 	 	 loss(train :: test): 1.3539 :: 1.3713
# 	 	 accuracy (train :: test): 58.1% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 60.5% :: 58.3%
#
# iteration 8_000  time: 41.7 seconds
# 	 	 loss(train :: test): 1.3549 :: 1.3287
# 	 	 accuracy (train :: test): 57.5% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 58.2% :: 59.4%
#
# iteration 10_000  time: 49.3 seconds
# 	 	 loss(train :: test): 1.3324 :: 1.3322
# 	 	 accuracy (train :: test): 58.2% :: 58.1%
# 	 	 accuracy (last character) (train :: test): 62.9% :: 62.1%
#
# iteration 12_000  time: 56.8 seconds
# 	 	 loss(train :: test): 1.3140 :: 1.3153
# 	 	 accuracy (train :: test): 58.4% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 59.8% :: 60.9%
#
# iteration 14_000  time: 64.3 seconds
# 	 	 loss(train :: test): 1.2854 :: 1.2992
# 	 	 accuracy (train :: test): 59.5% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 62.0%
#
# iteration 16_000  time: 71.8 seconds
# 	 	 loss(train :: test): 1.2770 :: 1.3027
# 	 	 accuracy (train :: test): 59.4% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 55.1% :: 61.3%
#
# iteration 18_000  time: 79.3 seconds
# 	 	 loss(train :: test): 1.3052 :: 1.3000
# 	 	 accuracy (train :: test): 59.0% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 60.5% :: 63.7%
#
# iteration 20_000  time: 86.8 seconds
# 	 	 loss(train :: test): 1.2476 :: 1.2951
# 	 	 accuracy (train :: test): 60.9% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 61.3% :: 62.1%
#
# iteration 22_000  time: 94.4 seconds
# 	 	 loss(train :: test): 1.2727 :: 1.2846
# 	 	 accuracy (train :: test): 59.2% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 61.9%
#
# iteration 24_000  time: 101.9 seconds
# 	 	 loss(train :: test): 1.2589 :: 1.2959
# 	 	 accuracy (train :: test): 60.5% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 67.6% :: 61.6%
#
# iteration 26_000  time: 109.4 seconds
# 	 	 loss(train :: test): 1.2773 :: 1.2828
# 	 	 accuracy (train :: test): 59.3% :: 59.9%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 65.0%
#
# iteration 28_000  time: 116.9 seconds
# 	 	 loss(train :: test): 1.2249 :: 1.2893
# 	 	 accuracy (train :: test): 60.7% :: 59.3%
# 	 	 accuracy (last character) (train :: test): 64.5% :: 60.3%
#
# iteration 30_000  time: 124.4 seconds
# 	 	 loss(train :: test): 1.2436 :: 1.2849
# 	 	 accuracy (train :: test): 60.4% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 63.9%
#
# iteration 32_000  time: 131.9 seconds
# 	 	 loss(train :: test): 1.2303 :: 1.2695
# 	 	 accuracy (train :: test): 61.5% :: 60.1%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 63.1%
#
# iteration 34_000  time: 139.4 seconds
# 	 	 loss(train :: test): 1.2494 :: 1.2901
# 	 	 accuracy (train :: test): 61.1% :: 59.5%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 61.1%
#
# iteration 36_000  time: 147.0 seconds
# 	 	 loss(train :: test): 1.2958 :: 1.2909
# 	 	 accuracy (train :: test): 59.0% :: 59.5%
# 	 	 accuracy (last character) (train :: test): 63.7% :: 60.9%
#
# iteration 38_000  time: 154.5 seconds
# 	 	 loss(train :: test): 1.2581 :: 1.2831
# 	 	 accuracy (train :: test): 60.1% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 63.6%
#
# iteration 40_000  time: 162.0 seconds
# 	 	 loss(train :: test): 1.2365 :: 1.2907
# 	 	 accuracy (train :: test): 61.4% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 68.4% :: 61.5%
#
# iteration 42_000  time: 169.5 seconds
# 	 	 loss(train :: test): 1.2357 :: 1.2700
# 	 	 accuracy (train :: test): 60.8% :: 60.0%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 62.7%
#
# iteration 44_000  time: 177.0 seconds
# 	 	 loss(train :: test): 1.2573 :: 1.2831
# 	 	 accuracy (train :: test): 60.2% :: 59.7%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 63.0%
#
# iteration 46_000  time: 184.5 seconds
# 	 	 loss(train :: test): 1.2608 :: 1.2586
# 	 	 accuracy (train :: test): 60.4% :: 60.3%
# 	 	 accuracy (last character) (train :: test): 62.9% :: 63.5%
#
# iteration 48_000  time: 192.0 seconds
# 	 	 loss(train :: test): 1.2683 :: 1.2553
# 	 	 accuracy (train :: test): 60.3% :: 60.5%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 64.0%
#
# iteration 50_000  time: 199.6 seconds
# 	 	 loss(train :: test): 1.2542 :: 1.2589
# 	 	 accuracy (train :: test): 61.0% :: 60.3%
# 	 	 accuracy (last character) (train :: test): 62.9% :: 62.0%
#
# iteration 52_000  time: 207.1 seconds
# 	 	 loss(train :: test): 1.2413 :: 1.2529
# 	 	 accuracy (train :: test): 60.5% :: 60.6%
# 	 	 accuracy (last character) (train :: test): 59.8% :: 63.4%
#
# iteration 54_000  time: 214.6 seconds
# 	 	 loss(train :: test): 1.2134 :: 1.2760
# 	 	 accuracy (train :: test): 61.3% :: 59.9%
# 	 	 accuracy (last character) (train :: test): 70.3% :: 61.5%
#
# iteration 56_000  time: 222.1 seconds
# 	 	 loss(train :: test): 1.2071 :: 1.2632
# 	 	 accuracy (train :: test): 61.6% :: 60.2%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 64.1%
#
# iteration 58_000  time: 229.6 seconds
# 	 	 loss(train :: test): 1.2158 :: 1.2796
# 	 	 accuracy (train :: test): 61.3% :: 59.8%
# 	 	 accuracy (last character) (train :: test): 62.1% :: 63.1%
#
# iteration 60_000  time: 237.2 seconds
# 	 	 loss(train :: test): 1.2291 :: 1.2735
# 	 	 accuracy (train :: test): 60.7% :: 60.0%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 63.5%
#
# iteration 62_000  time: 244.7 seconds
# 	 	 loss(train :: test): 1.2329 :: 1.2781
# 	 	 accuracy (train :: test): 61.4% :: 60.1%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 61.9%
#
# iteration 64_000  time: 252.2 seconds
# 	 	 loss(train :: test): 1.2120 :: 1.2588
# 	 	 accuracy (train :: test): 61.8% :: 60.4%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 62.7%
#
# iteration 66_000  time: 259.7 seconds
# 	 	 loss(train :: test): 1.2081 :: 1.2668
# 	 	 accuracy (train :: test): 61.8% :: 60.3%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 62.2%
#
# iteration 68_000  time: 267.2 seconds
# 	 	 loss(train :: test): 1.2285 :: 1.2712
# 	 	 accuracy (train :: test): 61.3% :: 60.0%
# 	 	 accuracy (last character) (train :: test): 66.8% :: 63.3%
#
# iteration 70_000  time: 274.7 seconds
# 	 	 loss(train :: test): 1.2383 :: 1.2592
# 	 	 accuracy (train :: test): 60.8% :: 60.5%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 62.0%
#
# iteration 72_000  time: 282.2 seconds
# 	 	 loss(train :: test): 1.2278 :: 1.2507
# 	 	 accuracy (train :: test): 61.0% :: 60.6%
# 	 	 accuracy (last character) (train :: test): 62.1% :: 63.2%
#
# iteration 74_000  time: 289.8 seconds
# 	 	 loss(train :: test): 1.2481 :: 1.2567
# 	 	 accuracy (train :: test): 60.6% :: 60.3%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 64.1%
#
# iteration 76_000  time: 297.3 seconds
# 	 	 loss(train :: test): 1.2207 :: 1.2569
# 	 	 accuracy (train :: test): 61.7% :: 60.3%
# 	 	 accuracy (last character) (train :: test): 64.5% :: 63.9%
#
# iteration 78_000  time: 304.8 seconds
# 	 	 loss(train :: test): 1.1655 :: 1.2776
# 	 	 accuracy (train :: test): 63.5% :: 59.7%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 63.8%
#
# iteration 80_000  time: 312.3 seconds
# 	 	 loss(train :: test): 1.2596 :: 1.2446
# 	 	 accuracy (train :: test): 60.2% :: 60.8%
# 	 	 accuracy (last character) (train :: test): 61.3% :: 63.2%
#
# iteration 82_000  time: 319.8 seconds
# 	 	 loss(train :: test): 1.2263 :: 1.2461
# 	 	 accuracy (train :: test): 61.1% :: 60.8%
# 	 	 accuracy (last character) (train :: test): 63.7% :: 65.3%
#
# iteration 84_000  time: 327.3 seconds
# 	 	 loss(train :: test): 1.2070 :: 1.2492
# 	 	 accuracy (train :: test): 62.2% :: 60.5%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 61.4%
#
# iteration 86_000  time: 334.9 seconds
# 	 	 loss(train :: test): 1.2308 :: 1.2463
# 	 	 accuracy (train :: test): 60.7% :: 60.7%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 60.8%
#
# iteration 88_000  time: 342.4 seconds
# 	 	 loss(train :: test): 1.1942 :: 1.2430
# 	 	 accuracy (train :: test): 62.6% :: 60.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 64.0%
#
# iteration 90_000  time: 349.9 seconds
# 	 	 loss(train :: test): 1.2236 :: 1.2471
# 	 	 accuracy (train :: test): 61.8% :: 61.1%
# 	 	 accuracy (last character) (train :: test): 64.5% :: 65.7%
#
# iteration 92_000  time: 357.4 seconds
# 	 	 loss(train :: test): 1.2048 :: 1.2527
# 	 	 accuracy (train :: test): 61.5% :: 60.6%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 64.9%
#
# iteration 94_000  time: 364.9 seconds
# 	 	 loss(train :: test): 1.2387 :: 1.2511
# 	 	 accuracy (train :: test): 60.7% :: 60.7%
# 	 	 accuracy (last character) (train :: test): 64.5% :: 66.7%
#
# iteration 96_000  time: 372.4 seconds
# 	 	 loss(train :: test): 1.2112 :: 1.2461
# 	 	 accuracy (train :: test): 62.3% :: 60.6%
# 	 	 accuracy (last character) (train :: test): 66.0% :: 66.7%
#
# iteration 98_000  time: 379.9 seconds
# 	 	 loss(train :: test): 1.2387 :: 1.2258
# 	 	 accuracy (train :: test): 61.0% :: 61.3%
# 	 	 accuracy (last character) (train :: test): 60.5% :: 66.0%
#
# iteration 99_999  time: 387.5 seconds
# 	 	 loss(train :: test): 1.2367 :: 1.2589
# 	 	 accuracy (train :: test): 61.4% :: 60.6%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 65.1%

# %%
# plot the loss history
plt.plot(swiglu_time_hist, swiglu_loss_hist, label="Train")
plt.plot(swiglu_time_test_hist, swiglu_loss_test_hist, label="Test")
plt.xlabel("Time (seconds)")
plt.xlim(0, 300)
plt.ylabel("Loss")
plt.title(" SwiGLU Loss History")

plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("./assets/base_swiglu_loss_history.png")
plt.show()

# %%
# Plot the test accuracy on the last character
plt.plot(swiglu_time_test_hist, swiglu_acc_last_test_hist, label="Test")
plt.xlabel("Time (seconds)")
plt.title(" SwiGLU Acc Last History")
plt.xlim(0, 300)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Combine train and test losses if needed
swiglu_train_loss = np.array([swiglu_time_hist, swiglu_loss_hist]).T  # shape: (iterations, 2)
swiglu_test_loss = np.array([swiglu_time_test_hist, swiglu_loss_test_hist]).T  # shape: (iterations, 2)
swiglu_test_acc_last = np.array([swiglu_time_test_hist, swiglu_acc_last_test_hist]).T  # shape: (iterations, 2)

# Save losses to CSV
df_train_loss = pd.DataFrame(swiglu_train_loss, columns=['time', 'loss'])
df_train_loss.to_csv('./data/swiglu_scale_train_loss.csv', index=False)

df_test_loss = pd.DataFrame(swiglu_test_loss, columns=['time', 'loss'])
df_test_loss.to_csv('./data/swiglu_scale_test_loss.csv', index=False)

df_test_acc_last = pd.DataFrame(swiglu_test_acc_last, columns=['time', 'loss'])
df_test_acc_last.to_csv('./data/swiglu_scale_test_acc_last.csv', index=False)

# %%
base_test_loss = pd.read_csv("./data/base_test_loss.csv")

plt.plot(base_test_loss['time'], base_test_loss['loss'], label="Base")
plt.plot(swiglu_time_test_hist, swiglu_loss_test_hist, label="SwiGLU")
plt.xlim(0, 300)
plt.legend()
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Loss")
plt.title("Loss History")

plt.show()
